# %% [markdown]
# **주요 내용은 emotionTraining.ipynb에 모두 있는 내용입니다.**
#
# **좀 더 원활한 training을 위해 코랩에서 진행하기 위해 만든 파일입니다.**

# %%
# 모델 load를 위해 yolov5 git clone
# !git clone https://github.com/ultralytics/yolov5

# %%
# 구글 드라이브에 접근하기 위한 코드
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# yolo 모델 load
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# %%
model

# %%
import uuid   # Unique identifier
import os
import time

# %%
# 드라이브에 있는 이미지 데이터와 labels들 현재 파일에 복사
# !cp -r ./drive/MyDrive/ColabNotebooks/deepLearningFinalProject/emotionData ./data

# %%
# 드라이브에 있는 dataset.yml 현재 파일에 복사
# !cp ./drive/MyDrive/ColabNotebooks/deepLearningFinalProject/yolov5/dataset.yaml ./yolov5/dataset.yml

# %%
# !ls

# %%
# custom yolo model training
# !cd yolov5 && python train.py --batch 16 --epochs 100 --data dataset.yml --weights yolov5s.pt --workers 2

# %%
# training 결과 압축
# !zip -r ./yolov5/runs/train/exp4.zip ./yolov5/runs/train/exp4/*

# %%
# training 결과 압축 파일 드라이브로 복사
# !cp ./yolov5/runs/train/exp4.zip ./drive/MyDrive/ColabNotebooks/deepLearningFinalProject/runs/exp4.zip
